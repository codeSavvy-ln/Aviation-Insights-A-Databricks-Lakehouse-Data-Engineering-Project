-- %%
select * from csv.`abfss://bronze@revtraining.dfs.core.windows.net/dataset/airlines.csv`

-- %% [markdown]
-- **Airlines**

-- %%
%python
df_airlines =(spark.read.format("csv")
              .option("header", "true")
              .option("inferSchema", "true")
              .load("abfss://bronze@revtraining.dfs.core.windows.net/dataset/airlines.csv")               

)

-- %%
CREATE TABLE IF NOT EXISTS aviation_project.bronze.airlines
   USING DELTA
   LOCATION 'abfss://bronze@revtraining.dfs.core.windows.net/Tables/airlines'

-- %%
%python
df_airlines.write.mode("overwrite").option(
       "overwriteSchema", "true"
   ).format("delta").save("abfss://bronze@revtraining.dfs.core.windows.net/Tables/airlines")

-- %%
select * from aviation_project.bronze.airlines

-- %%
%python
df = spark.table("aviation_project.bronze.airlines")
df.printSchema()

-- %%
DESCRIBE TABLE aviation_project.bronze.airlines

-- %% [markdown]
-- **Airports**

-- %%
%python
df_airports =(spark.read.format("csv")
              .option("header", "true")
              .option("inferSchema", "true")
              .load("abfss://bronze@revtraining.dfs.core.windows.net/dataset/airports.csv")               

)

-- %%
CREATE TABLE IF NOT EXISTS aviation_project.bronze.airports
   USING DELTA
   LOCATION 'abfss://bronze@revtraining.dfs.core.windows.net/Tables/airports'
;

-- %%
%python
df_airports.write.mode("overwrite").option(
       "overwriteSchema", "true"
   ).format("delta").save("abfss://bronze@revtraining.dfs.core.windows.net/Tables/airports")

-- %%
select * from aviation_project.bronze.airports

-- %%
SELECT 
  SUM(CASE WHEN IATA_CODE IS NULL THEN 1 ELSE 0 END) AS IATA_nulls,
  SUM(CASE WHEN Airport IS NULL THEN 1 ELSE 0 END) AS Airport_nulls,
  SUM(CASE WHEN city IS NULL THEN 1 ELSE 0 END) AS city_nulls,
  SUM(CASE WHEN state IS NULL THEN 1 ELSE 0 END) AS state_nulls,
  SUM(CASE WHEN country IS NULL THEN 1 ELSE 0 END) AS country_nulls,
  SUM(CASE WHEN latitude IS NULL THEN 1 ELSE 0 END) AS latitude_nulls,
  SUM(CASE WHEN longitude IS NULL THEN 1 ELSE 0 END) AS longitude_nulls

FROM aviation_project.bronze.airports;

-- %%
DESCRIBE TABLE aviation_project.bronze.airports

-- %% [markdown]
-- **Flights**

-- %%
%python
df_flights =(spark.read.format("csv")
              .option("header", "true")
              .option("inferSchema", "true")
              .load("abfss://bronze@revtraining.dfs.core.windows.net/dataset/flights_sample.csv")               

)

-- %%
CREATE TABLE IF NOT EXISTS aviation_project.bronze.flights
   USING DELTA
   LOCATION 'abfss://bronze@revtraining.dfs.core.windows.net/Tables/flights'
;

-- %%
%python
df_flights.write.mode("overwrite").option(
       "overwriteSchema", "true"
   ).format("delta").save("abfss://bronze@revtraining.dfs.core.windows.net/Tables/flights")

-- %%
Select * from aviation_project.bronze.flights
where day > 1

-- %%
DESCRIBE TABLE aviation_project.bronze.flights

-- %%
%python
df_count = spark.table("aviation_project.bronze.flights").count()
display(df_count)

-- %%
%python
files_df = spark.read.format("csv").option("header", "true").load("abfss://bronze@revtraining.dfs.core.windows.net/dataset/Streaming/flights_latest1.csv")
files_df.show()
