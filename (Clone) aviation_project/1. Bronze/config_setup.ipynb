# %%
# %sql
create catalog aviation_project

# %%
# %sql
create schema if not exists aviation_project.bronze

# %%
# %sql
create schema if not exists aviation_project.silver

# %%
# %sql
create schema if not exists aviation_project.gold

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS aviation_project_ext_lcn
URL 'abfss://bronze@revtraining.dfs.core.windows.net/'
WITH (CREDENTIAL aviation_project_cred);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS aviation_project_ext_lcn_silver
URL 'abfss://silver@revtraining.dfs.core.windows.net/'
WITH (CREDENTIAL aviation_project_cred);
