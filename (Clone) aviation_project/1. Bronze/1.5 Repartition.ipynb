# %%
df = spark.read.option("header", True).csv("abfss://bronze@revtraining.dfs.core.windows.net/dataset/flights_latest.csv")

# %%
df.repartition(10) \
  .write \
  .mode("overwrite") \
  .option("header", True) \
  .csv("abfss://bronze@revtraining.dfs.core.windows.net/dataset/Streaming/")

# %%
# %sql
select count(*) from aviation_project.bronze.flights_stream

# %%
stream_df.show()
