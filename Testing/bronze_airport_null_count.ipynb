# %%
null_count = spark.sql("""select count(IATA_CODE) as null_count from aviation_project.bronze.airports
where latitude is null or longitude is null or airport is null or city is null or state is null or country is null""")

# %%
null_count = spark.sql("""select count(IATA_CODE) as null_count from aviation_project.bronze.airports
where latitude is null or longitude is null or airport is null or city is null or state is null or country is null""")

# %%
# Get the value from the DataFrame
null_count_value = null_count.collect()[0]['null_count']

# Store the value using dbutils
dbutils.jobs.taskValues.set(key="null_count", value=null_count_value)

# %%
print(null_count_value)
